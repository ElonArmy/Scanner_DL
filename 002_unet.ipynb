# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd
import glob

import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Nadam
import tensorflow as tf
import tensorflow.python.keras.backend as k

# %%
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 1


#데이터 경로 지정  
TRAIN_PATH = './sm_data/train/'
TEST_PATH = './sm_data/test/'

# UserWarning을 무시하는 설정(없음 OK)
warnings.filterwarnings('ignore', category=UserWarning, module='skimage')

#이미지 파일명을 리스트 형식으로 리턴  
train_imgs = glob.glob(TRAIN_PATH+'org/*.png')
train_masks = glob.glob(TRAIN_PATH+'label/*.png')
test_imgs = glob.glob(TEST_PATH+'org/*.png')
test_masks = glob.glob(TEST_PATH+'label/*.png')

#리스트 길이 리턴  
num_of_train_imgs = len(train_imgs)
num_of_train_masks = len(train_masks)
if num_of_train_imgs != num_of_train_masks:
    print('invalid datasets, please check train data')
    
    
#각이미지를 배열로 리턴
#image 
X_train = np.zeros((num_of_train_imgs, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
# mask
Y_train = np.zeros((num_of_train_masks, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()

print(imread(train_imgs[0]))

for n in range(num_of_train_imgs):
    X_train[n] = imread(train_imgs[n],as_gray=True).reshape(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
    Y_train[n] = imread(train_masks[n],as_gray=True).reshape(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)


# 테스트 이미지를 배열로 리턴
X_test = np.zeros((len(test_imgs), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_test = np.zeros((len(test_masks), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)

print('Getting test images ... ')
sys.stdout.flush()

for n in range(len(test_imgs)):
    X_test[n] = imread(test_imgs[n],as_gray=True).reshape(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
    Y_test[n] = imread(test_masks[n],as_gray=True).reshape(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
print('Preparing is Done!')
# Out:
# Getting and resizing train images and masks ...
# [[  0   0   0 ...   5   5   5]
#  [  0   0   0 ...   5   5   5]
#  [  0   0   0 ...   5   5   5]
#  ...
#  [ 25 255 255 ... 255 255 255]
#  [ 30 255 255 ... 255 255 255]
#  [ 30 255 255 ... 255 255 255]]
# Getting test images ...
# Preparing is Done!

# %%
###이미지 확인 #####
ix = random.randint(0, len(train_imgs))
imshow(X_train[ix].reshape(IMG_HEIGHT, IMG_WIDTH))
plt.show()
imshow(np.squeeze(Y_train[ix].reshape(IMG_HEIGHT, IMG_WIDTH)))
plt.show()

# %%
# U-Net model 
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255.) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = BatchNormalization() (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same') (p1)
c2 = LeakyReLU()(c2)
c2 = BatchNormalization() (c2)
c2 = Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same') (c2)
c2 = LeakyReLU()(c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same') (p2)
c3 = LeakyReLU()(c3)
c3 = BatchNormalization() (c3)
c3 = Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same') (c3)
c3 = LeakyReLU()(c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), kernel_initializer='he_normal', padding='same') (p3)
c4 = LeakyReLU()(c4)
c4 = BatchNormalization() (c4)
c4 = Conv2D(128, (3, 3), kernel_initializer='he_normal', padding='same') (c4)
c4 = LeakyReLU()(c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = BatchNormalization() (c5)
c5 = Conv2D(256, (3, 3), activation='elu',kernel_initializer='he_normal', padding='same') (c5)

#===========================================

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), kernel_initializer='he_normal', padding='same') (u6)
c6 = LeakyReLU()(c6)
c6 = BatchNormalization() (c6)
c6 = Conv2D(128, (3, 3), kernel_initializer='he_normal', padding='same') (c6)
c6 = LeakyReLU()(c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same') (u7)
c7 = LeakyReLU()(c7)
c7 = BatchNormalization() (c7)
c7 = Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same') (c7)
c7 = LeakyReLU()(c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same') (u8)
c8 = LeakyReLU()(c8)
c8 = BatchNormalization() (c8)
c8 = Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same') (c8)
c8 = LeakyReLU()(c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = BatchNormalization(momentum=0.9) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])

# %%
model.compile(optimizer=Nadam(learning_rate=2e-5), loss='binary_crossentropy', metrics=['binary_accuracy','acc'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  lambda (Lambda)                (None, 256, 256, 1)  0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 256, 256, 16  160         ['lambda[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 16  2320        ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 16  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 32  4640        ['max_pooling2d[0][0]']
#                                 )
#
#  leaky_re_lu (LeakyReLU)        (None, 128, 128, 32  0           ['conv2d_2[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 32  128        ['leaky_re_lu[0][0]']
#  rmalization)                   )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 32  9248        ['batch_normalization_1[0][0]']
#                                 )
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 128, 128, 32  0           ['conv2d_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)  0           ['leaky_re_lu_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 64, 64, 64)   0           ['conv2d_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 64)  256         ['leaky_re_lu_2[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 64)   36928       ['batch_normalization_2[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 64, 64, 64)   0           ['conv2d_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)  0           ['leaky_re_lu_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 32, 32, 128)  0           ['conv2d_6[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 128)  512        ['leaky_re_lu_4[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 128)  147584      ['batch_normalization_3[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 32, 32, 128)  0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0          ['leaky_re_lu_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 256)  590080      ['batch_normalization_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 128)  131200     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'leaky_re_lu_5[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 32, 32, 128)  0           ['conv2d_10[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 128)  512        ['leaky_re_lu_6[0][0]']
#  rmalization)
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 128)  147584      ['batch_normalization_5[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 32, 32, 128)  0           ['conv2d_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 64)  32832       ['leaky_re_lu_7[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'leaky_re_lu_3[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_1[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 64, 64, 64)   0           ['conv2d_12[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 64)  256         ['leaky_re_lu_8[0][0]']
#  rmalization)
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_6[0][0]']
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 64, 64, 64)   0           ['conv2d_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 32  8224       ['leaky_re_lu_9[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'leaky_re_lu_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_2[0][0]']
#                                 )
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 128, 128, 32  0           ['conv2d_14[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 32  128        ['leaky_re_lu_10[0][0]']
#  rmalization)                   )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 32  9248        ['batch_normalization_7[0][0]']
#                                 )
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 128, 128, 32  0           ['conv2d_15[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 16  2064       ['leaky_re_lu_11[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 256, 256, 16  64         ['conv2d_16[0][0]']
#  rmalization)                   )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 16  2320        ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  17          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 1,943,761
# Trainable params: 1,942,289
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
checkpointer = ModelCheckpoint('model-u-net.h5', verbose=1, save_best_only=True)
reduceLr = ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=7)

results = model.fit(X_train, 
                    Y_train, 
                    validation_split=0.1, 
                    batch_size=3, 
                    epochs=50,
                    callbacks=[reduceLr, checkpointer])
# Out:
# Epoch 1/50
# 15/15 [==============================] - ETA: 0s - loss: -9.5645 - binary_accuracy: 0.3047 - acc: 0.3047
# Epoch 1: val_loss improved from inf to 47.57925, saving model to model-u-net.h5
# 15/15 [==============================] - 36s 1s/step - loss: -9.5645 - binary_accuracy: 0.3047 - acc: 0.3047 - val_loss: 47.5792 - val_binary_accuracy: 0.5886 - val_acc: 0.5886 - lr: 2.0000e-05
# Epoch 2/50
# 15/15 [==============================] - ETA: 0s - loss: -61.1098 - binary_accuracy: 0.3740 - acc: 0.3740
# Epoch 2: val_loss did not improve from 47.57925
# 15/15 [==============================] - 17s 1s/step - loss: -61.1098 - binary_accuracy: 0.3740 - acc: 0.3740 - val_loss: 75.3639 - val_binary_accuracy: 0.7022 - val_acc: 0.7022 - lr: 2.0000e-05
# Epoch 3/50
# 15/15 [==============================] - ETA: 0s - loss: -123.3683 - binary_accuracy: 0.4345 - acc: 0.4345
# Epoch 3: val_loss did not improve from 47.57925
# 15/15 [==============================] - 17s 1s/step - loss: -123.3683 - binary_accuracy: 0.4345 - acc: 0.4345 - val_loss: 86.6385 - val_binary_accuracy: 0.6731 - val_acc: 0.6731 - lr: 2.0000e-05
# Epoch 4/50
# 15/15 [==============================] - ETA: 0s - loss: -175.7955 - binary_accuracy: 0.4689 - acc: 0.4689
# Epoch 4: val_loss did not improve from 47.57925
# 15/15 [==============================] - 17s 1s/step - loss: -175.7955 - binary_accuracy: 0.4689 - acc: 0.4689 - val_loss: 83.0278 - val_binary_accuracy: 0.6220 - val_acc: 0.6220 - lr: 2.0000e-05
# Epoch 5/50
# 15/15 [==============================] - ETA: 0s - loss: -218.8342 - binary_accuracy: 0.4853 - acc: 0.4853
# Epoch 5: val_loss did not improve from 47.57925
# 15/15 [==============================] - 17s 1s/step - loss: -218.8342 - binary_accuracy: 0.4853 - acc: 0.4853 - val_loss: 62.9408 - val_binary_accuracy: 0.6009 - val_acc: 0.6009 - lr: 2.0000e-05
# Epoch 6/50
# 15/15 [==============================] - ETA: 0s - loss: -260.2997 - binary_accuracy: 0.4940 - acc: 0.4940
# Epoch 6: val_loss improved from 47.57925 to 16.51708, saving model to model-u-net.h5
# 15/15 [==============================] - 20s 1s/step - loss: -260.2997 - binary_accuracy: 0.4940 - acc: 0.4940 - val_loss: 16.5171 - val_binary_accuracy: 0.5830 - val_acc: 0.5830 - lr: 2.0000e-05
# Epoch 7/50
# 15/15 [==============================] - ETA: 0s - loss: -296.0623 - binary_accuracy: 0.5012 - acc: 0.5012
# Epoch 7: val_loss improved from 16.51708 to -29.20483, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -296.0623 - binary_accuracy: 0.5012 - acc: 0.5012 - val_loss: -29.2048 - val_binary_accuracy: 0.5698 - val_acc: 0.5698 - lr: 2.0000e-05
# Epoch 8/50
# 15/15 [==============================] - ETA: 0s - loss: -332.6656 - binary_accuracy: 0.5091 - acc: 0.5091
# Epoch 8: val_loss improved from -29.20483 to -77.40593, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -332.6656 - binary_accuracy: 0.5091 - acc: 0.5091 - val_loss: -77.4059 - val_binary_accuracy: 0.5609 - val_acc: 0.5609 - lr: 2.0000e-05
# Epoch 9/50
# 15/15 [==============================] - ETA: 0s - loss: -371.7578 - binary_accuracy: 0.5261 - acc: 0.5261
# Epoch 9: val_loss improved from -77.40593 to -140.12997, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -371.7578 - binary_accuracy: 0.5261 - acc: 0.5261 - val_loss: -140.1300 - val_binary_accuracy: 0.5487 - val_acc: 0.5487 - lr: 2.0000e-05
# Epoch 10/50
# 15/15 [==============================] - ETA: 0s - loss: -407.0411 - binary_accuracy: 0.5369 - acc: 0.5369
# Epoch 10: val_loss did not improve from -140.12997
# 15/15 [==============================] - 17s 1s/step - loss: -407.0411 - binary_accuracy: 0.5369 - acc: 0.5369 - val_loss: -125.6057 - val_binary_accuracy: 0.5588 - val_acc: 0.5588 - lr: 2.0000e-05
# Epoch 11/50
# 15/15 [==============================] - ETA: 0s - loss: -439.5673 - binary_accuracy: 0.5497 - acc: 0.5497
# Epoch 11: val_loss improved from -140.12997 to -167.31685, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -439.5673 - binary_accuracy: 0.5497 - acc: 0.5497 - val_loss: -167.3168 - val_binary_accuracy: 0.5739 - val_acc: 0.5739 - lr: 2.0000e-05
# Epoch 12/50
# 15/15 [==============================] - ETA: 0s - loss: -471.6255 - binary_accuracy: 0.5648 - acc: 0.5648
# Epoch 12: val_loss improved from -167.31685 to -276.11661, saving model to model-u-net.h5
# 15/15 [==============================] - 19s 1s/step - loss: -471.6255 - binary_accuracy: 0.5648 - acc: 0.5648 - val_loss: -276.1166 - val_binary_accuracy: 0.5732 - val_acc: 0.5732 - lr: 2.0000e-05
# Epoch 13/50
# 15/15 [==============================] - ETA: 0s - loss: -504.7379 - binary_accuracy: 0.5779 - acc: 0.5779
# Epoch 13: val_loss did not improve from -276.11661
# 15/15 [==============================] - 17s 1s/step - loss: -504.7379 - binary_accuracy: 0.5779 - acc: 0.5779 - val_loss: -246.3855 - val_binary_accuracy: 0.6165 - val_acc: 0.6165 - lr: 2.0000e-05
# Epoch 14/50
# 15/15 [==============================] - ETA: 0s - loss: -534.4309 - binary_accuracy: 0.5927 - acc: 0.5927
# Epoch 14: val_loss improved from -276.11661 to -311.73859, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -534.4309 - binary_accuracy: 0.5927 - acc: 0.5927 - val_loss: -311.7386 - val_binary_accuracy: 0.6321 - val_acc: 0.6321 - lr: 2.0000e-05
# Epoch 15/50
# 15/15 [==============================] - ETA: 0s - loss: -568.3439 - binary_accuracy: 0.6034 - acc: 0.6034
# Epoch 15: val_loss did not improve from -311.73859
# 15/15 [==============================] - 17s 1s/step - loss: -568.3439 - binary_accuracy: 0.6034 - acc: 0.6034 - val_loss: -276.1299 - val_binary_accuracy: 0.6545 - val_acc: 0.6545 - lr: 2.0000e-05
# Epoch 16/50
# 15/15 [==============================] - ETA: 0s - loss: -600.5770 - binary_accuracy: 0.6117 - acc: 0.6117
# Epoch 16: val_loss did not improve from -311.73859
# 15/15 [==============================] - 17s 1s/step - loss: -600.5770 - binary_accuracy: 0.6117 - acc: 0.6117 - val_loss: -304.0223 - val_binary_accuracy: 0.6671 - val_acc: 0.6671 - lr: 2.0000e-05
# Epoch 17/50
# 15/15 [==============================] - ETA: 0s - loss: -629.5262 - binary_accuracy: 0.6226 - acc: 0.6226
# Epoch 17: val_loss improved from -311.73859 to -396.59515, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -629.5262 - binary_accuracy: 0.6226 - acc: 0.6226 - val_loss: -396.5952 - val_binary_accuracy: 0.6690 - val_acc: 0.6690 - lr: 2.0000e-05
# Epoch 18/50
# 15/15 [==============================] - ETA: 0s - loss: -659.5524 - binary_accuracy: 0.6305 - acc: 0.6305
# Epoch 18: val_loss improved from -396.59515 to -477.26846, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -659.5524 - binary_accuracy: 0.6305 - acc: 0.6305 - val_loss: -477.2685 - val_binary_accuracy: 0.6653 - val_acc: 0.6653 - lr: 2.0000e-05
# Epoch 19/50
# 15/15 [==============================] - ETA: 0s - loss: -687.4674 - binary_accuracy: 0.6366 - acc: 0.6366
# Epoch 19: val_loss did not improve from -477.26846
# 15/15 [==============================] - 17s 1s/step - loss: -687.4674 - binary_accuracy: 0.6366 - acc: 0.6366 - val_loss: -469.2897 - val_binary_accuracy: 0.6781 - val_acc: 0.6781 - lr: 2.0000e-05
# Epoch 20/50
# 15/15 [==============================] - ETA: 0s - loss: -717.6566 - binary_accuracy: 0.6445 - acc: 0.6445
# Epoch 20: val_loss improved from -477.26846 to -557.02966, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -717.6566 - binary_accuracy: 0.6445 - acc: 0.6445 - val_loss: -557.0297 - val_binary_accuracy: 0.6738 - val_acc: 0.6738 - lr: 2.0000e-05
# Epoch 21/50
# 15/15 [==============================] - ETA: 0s - loss: -746.7198 - binary_accuracy: 0.6482 - acc: 0.6482
# Epoch 21: val_loss improved from -557.02966 to -592.32581, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -746.7198 - binary_accuracy: 0.6482 - acc: 0.6482 - val_loss: -592.3258 - val_binary_accuracy: 0.6750 - val_acc: 0.6750 - lr: 2.0000e-05
# Epoch 22/50
# 15/15 [==============================] - ETA: 0s - loss: -774.5420 - binary_accuracy: 0.6518 - acc: 0.6518
# Epoch 22: val_loss improved from -592.32581 to -626.76990, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -774.5420 - binary_accuracy: 0.6518 - acc: 0.6518 - val_loss: -626.7699 - val_binary_accuracy: 0.6758 - val_acc: 0.6758 - lr: 2.0000e-05
# Epoch 23/50
# 15/15 [==============================] - ETA: 0s - loss: -804.1733 - binary_accuracy: 0.6535 - acc: 0.6535
# Epoch 23: val_loss improved from -626.76990 to -647.73871, saving model to model-u-net.h5
# 15/15 [==============================] - 19s 1s/step - loss: -804.1733 - binary_accuracy: 0.6535 - acc: 0.6535 - val_loss: -647.7387 - val_binary_accuracy: 0.6776 - val_acc: 0.6776 - lr: 2.0000e-05
# Epoch 24/50
# 15/15 [==============================] - ETA: 0s - loss: -829.7551 - binary_accuracy: 0.6556 - acc: 0.6556
# Epoch 24: val_loss improved from -647.73871 to -684.55969, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -829.7551 - binary_accuracy: 0.6556 - acc: 0.6556 - val_loss: -684.5597 - val_binary_accuracy: 0.6776 - val_acc: 0.6776 - lr: 2.0000e-05
# Epoch 25/50
# 15/15 [==============================] - ETA: 0s - loss: -858.4595 - binary_accuracy: 0.6588 - acc: 0.6588
# Epoch 25: val_loss improved from -684.55969 to -757.27820, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -858.4595 - binary_accuracy: 0.6588 - acc: 0.6588 - val_loss: -757.2782 - val_binary_accuracy: 0.6714 - val_acc: 0.6714 - lr: 2.0000e-05
# Epoch 26/50
# 15/15 [==============================] - ETA: 0s - loss: -883.6902 - binary_accuracy: 0.6596 - acc: 0.6596
# Epoch 26: val_loss did not improve from -757.27820
# 15/15 [==============================] - 17s 1s/step - loss: -883.6902 - binary_accuracy: 0.6596 - acc: 0.6596 - val_loss: -729.3361 - val_binary_accuracy: 0.6788 - val_acc: 0.6788 - lr: 2.0000e-05
# Epoch 27/50
# 15/15 [==============================] - ETA: 0s - loss: -908.6719 - binary_accuracy: 0.6599 - acc: 0.6599
# Epoch 27: val_loss improved from -757.27820 to -764.21399, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -908.6719 - binary_accuracy: 0.6599 - acc: 0.6599 - val_loss: -764.2140 - val_binary_accuracy: 0.6803 - val_acc: 0.6803 - lr: 2.0000e-05
# Epoch 28/50
# 15/15 [==============================] - ETA: 0s - loss: -934.3680 - binary_accuracy: 0.6630 - acc: 0.6630
# Epoch 28: val_loss did not improve from -764.21399
# 15/15 [==============================] - 17s 1s/step - loss: -934.3680 - binary_accuracy: 0.6630 - acc: 0.6630 - val_loss: -757.3042 - val_binary_accuracy: 0.6813 - val_acc: 0.6813 - lr: 2.0000e-05
# Epoch 29/50
# 15/15 [==============================] - ETA: 0s - loss: -958.3785 - binary_accuracy: 0.6631 - acc: 0.6631
# Epoch 29: val_loss improved from -764.21399 to -840.67151, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -958.3785 - binary_accuracy: 0.6631 - acc: 0.6631 - val_loss: -840.6715 - val_binary_accuracy: 0.6731 - val_acc: 0.6731 - lr: 2.0000e-05
# Epoch 30/50
# 15/15 [==============================] - ETA: 0s - loss: -980.5539 - binary_accuracy: 0.6635 - acc: 0.6635
# Epoch 30: val_loss did not improve from -840.67151
# 15/15 [==============================] - 17s 1s/step - loss: -980.5539 - binary_accuracy: 0.6635 - acc: 0.6635 - val_loss: -836.3912 - val_binary_accuracy: 0.6806 - val_acc: 0.6806 - lr: 2.0000e-05
# Epoch 31/50
# 15/15 [==============================] - ETA: 0s - loss: -1004.4850 - binary_accuracy: 0.6646 - acc: 0.6646
# Epoch 31: val_loss improved from -840.67151 to -887.82971, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1004.4850 - binary_accuracy: 0.6646 - acc: 0.6646 - val_loss: -887.8297 - val_binary_accuracy: 0.6779 - val_acc: 0.6779 - lr: 2.0000e-05
# Epoch 32/50
# 15/15 [==============================] - ETA: 0s - loss: -1028.8584 - binary_accuracy: 0.6661 - acc: 0.6661
# Epoch 32: val_loss improved from -887.82971 to -900.05505, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1028.8584 - binary_accuracy: 0.6661 - acc: 0.6661 - val_loss: -900.0551 - val_binary_accuracy: 0.6777 - val_acc: 0.6777 - lr: 2.0000e-05
# Epoch 33/50
# 15/15 [==============================] - ETA: 0s - loss: -1051.4645 - binary_accuracy: 0.6659 - acc: 0.6659
# Epoch 33: val_loss improved from -900.05505 to -953.09900, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1051.4645 - binary_accuracy: 0.6659 - acc: 0.6659 - val_loss: -953.0990 - val_binary_accuracy: 0.6736 - val_acc: 0.6736 - lr: 2.0000e-05
# Epoch 34/50
# 15/15 [==============================] - ETA: 0s - loss: -1073.0530 - binary_accuracy: 0.6673 - acc: 0.6673
# Epoch 34: val_loss improved from -953.09900 to -1030.55078, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1073.0530 - binary_accuracy: 0.6673 - acc: 0.6673 - val_loss: -1030.5508 - val_binary_accuracy: 0.6659 - val_acc: 0.6659 - lr: 2.0000e-05
# Epoch 35/50
# 15/15 [==============================] - ETA: 0s - loss: -1093.7745 - binary_accuracy: 0.6665 - acc: 0.6665
# Epoch 35: val_loss did not improve from -1030.55078
# 15/15 [==============================] - 17s 1s/step - loss: -1093.7745 - binary_accuracy: 0.6665 - acc: 0.6665 - val_loss: -1017.3024 - val_binary_accuracy: 0.6726 - val_acc: 0.6726 - lr: 2.0000e-05
# Epoch 36/50
# 15/15 [==============================] - ETA: 0s - loss: -1116.2278 - binary_accuracy: 0.6688 - acc: 0.6688
# Epoch 36: val_loss improved from -1030.55078 to -1052.95544, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1116.2278 - binary_accuracy: 0.6688 - acc: 0.6688 - val_loss: -1052.9554 - val_binary_accuracy: 0.6710 - val_acc: 0.6710 - lr: 2.0000e-05
# Epoch 37/50
# 15/15 [==============================] - ETA: 0s - loss: -1136.8568 - binary_accuracy: 0.6679 - acc: 0.6679
# Epoch 37: val_loss did not improve from -1052.95544
# 15/15 [==============================] - 17s 1s/step - loss: -1136.8568 - binary_accuracy: 0.6679 - acc: 0.6679 - val_loss: -1047.5105 - val_binary_accuracy: 0.6737 - val_acc: 0.6737 - lr: 2.0000e-05
# Epoch 38/50
# 15/15 [==============================] - ETA: 0s - loss: -1158.1967 - binary_accuracy: 0.6690 - acc: 0.6690
# Epoch 38: val_loss improved from -1052.95544 to -1084.23987, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1158.1967 - binary_accuracy: 0.6690 - acc: 0.6690 - val_loss: -1084.2399 - val_binary_accuracy: 0.6716 - val_acc: 0.6716 - lr: 2.0000e-05
# Epoch 39/50
# 15/15 [==============================] - ETA: 0s - loss: -1183.4045 - binary_accuracy: 0.6701 - acc: 0.6701
# Epoch 39: val_loss improved from -1084.23987 to -1166.72046, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1183.4045 - binary_accuracy: 0.6701 - acc: 0.6701 - val_loss: -1166.7205 - val_binary_accuracy: 0.6644 - val_acc: 0.6644 - lr: 2.0000e-05
# Epoch 40/50
# 15/15 [==============================] - ETA: 0s - loss: -1204.0361 - binary_accuracy: 0.6707 - acc: 0.6707
# Epoch 40: val_loss did not improve from -1166.72046
# 15/15 [==============================] - 17s 1s/step - loss: -1204.0361 - binary_accuracy: 0.6707 - acc: 0.6707 - val_loss: -1165.3013 - val_binary_accuracy: 0.6673 - val_acc: 0.6673 - lr: 2.0000e-05
# Epoch 41/50
# 15/15 [==============================] - ETA: 0s - loss: -1227.7166 - binary_accuracy: 0.6709 - acc: 0.6709
# Epoch 41: val_loss improved from -1166.72046 to -1207.70679, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1227.7166 - binary_accuracy: 0.6709 - acc: 0.6709 - val_loss: -1207.7068 - val_binary_accuracy: 0.6682 - val_acc: 0.6682 - lr: 2.0000e-05
# Epoch 42/50
# 15/15 [==============================] - ETA: 0s - loss: -1250.0776 - binary_accuracy: 0.6720 - acc: 0.6720
# Epoch 42: val_loss improved from -1207.70679 to -1242.53442, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1250.0776 - binary_accuracy: 0.6720 - acc: 0.6720 - val_loss: -1242.5344 - val_binary_accuracy: 0.6669 - val_acc: 0.6669 - lr: 2.0000e-05
# Epoch 43/50
# 15/15 [==============================] - ETA: 0s - loss: -1273.1549 - binary_accuracy: 0.6723 - acc: 0.6723
# Epoch 43: val_loss improved from -1242.53442 to -1260.71228, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1273.1549 - binary_accuracy: 0.6723 - acc: 0.6723 - val_loss: -1260.7123 - val_binary_accuracy: 0.6702 - val_acc: 0.6702 - lr: 2.0000e-05
# Epoch 44/50
# 15/15 [==============================] - ETA: 0s - loss: -1296.3196 - binary_accuracy: 0.6741 - acc: 0.6741
# Epoch 44: val_loss did not improve from -1260.71228
# 15/15 [==============================] - 17s 1s/step - loss: -1296.3196 - binary_accuracy: 0.6741 - acc: 0.6741 - val_loss: -1258.4502 - val_binary_accuracy: 0.6698 - val_acc: 0.6698 - lr: 2.0000e-05
# Epoch 45/50
# 15/15 [==============================] - ETA: 0s - loss: -1319.8514 - binary_accuracy: 0.6740 - acc: 0.6740
# Epoch 45: val_loss improved from -1260.71228 to -1281.76611, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1319.8514 - binary_accuracy: 0.6740 - acc: 0.6740 - val_loss: -1281.7661 - val_binary_accuracy: 0.6722 - val_acc: 0.6722 - lr: 2.0000e-05
# Epoch 46/50
# 15/15 [==============================] - ETA: 0s - loss: -1343.4014 - binary_accuracy: 0.6741 - acc: 0.6741
# Epoch 46: val_loss improved from -1281.76611 to -1304.00500, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1343.4014 - binary_accuracy: 0.6741 - acc: 0.6741 - val_loss: -1304.0050 - val_binary_accuracy: 0.6732 - val_acc: 0.6732 - lr: 2.0000e-05
# Epoch 47/50
# 15/15 [==============================] - ETA: 0s - loss: -1365.0292 - binary_accuracy: 0.6755 - acc: 0.6755
# Epoch 47: val_loss improved from -1304.00500 to -1359.68042, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1365.0292 - binary_accuracy: 0.6755 - acc: 0.6755 - val_loss: -1359.6804 - val_binary_accuracy: 0.6705 - val_acc: 0.6705 - lr: 2.0000e-05
# Epoch 48/50
# 15/15 [==============================] - ETA: 0s - loss: -1388.5250 - binary_accuracy: 0.6758 - acc: 0.6758
# Epoch 48: val_loss improved from -1359.68042 to -1372.80798, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1388.5250 - binary_accuracy: 0.6758 - acc: 0.6758 - val_loss: -1372.8080 - val_binary_accuracy: 0.6695 - val_acc: 0.6695 - lr: 2.0000e-05
# Epoch 49/50
# 15/15 [==============================] - ETA: 0s - loss: -1412.9009 - binary_accuracy: 0.6761 - acc: 0.6761
# Epoch 49: val_loss improved from -1372.80798 to -1389.01599, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1412.9009 - binary_accuracy: 0.6761 - acc: 0.6761 - val_loss: -1389.0160 - val_binary_accuracy: 0.6684 - val_acc: 0.6684 - lr: 2.0000e-05
# Epoch 50/50
# 15/15 [==============================] - ETA: 0s - loss: -1433.9841 - binary_accuracy: 0.6765 - acc: 0.6765
# Epoch 50: val_loss improved from -1389.01599 to -1411.61108, saving model to model-u-net.h5
# 15/15 [==============================] - 18s 1s/step - loss: -1433.9841 - binary_accuracy: 0.6765 - acc: 0.6765 - val_loss: -1411.6111 - val_binary_accuracy: 0.6675 - val_acc: 0.6675 - lr: 2.0000e-05

# %%
model = load_model('model-u-net.h5')
preds_test = model.predict(X_test, verbose=1)

#픽셀  평가 결과를 0.5의 임계치로 0 or 255로 변환(평가 결과를 바이너리 이미지로 변환).
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# 임의 결과로 하나를 리턴 받아 표시 
ix = random.randint(0, len(preds_test_t))
print('원본 이미지')
imshow(X_test[ix].reshape(IMG_HEIGHT, IMG_WIDTH))
plt.show()
print('원본 이미지의 세그먼테이션')
imshow(Y_test[ix].reshape(IMG_HEIGHT, IMG_WIDTH))
plt.show()
print('모델의 예측 세그먼테이션')
imshow(np.squeeze(preds_test_t[ix].reshape(IMG_HEIGHT, IMG_WIDTH)))
plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step
# 원본 이미지
# 원본 이미지의 세그먼테이션
# 모델의 예측 세그먼테이션
