# %% [markdown]
# # U-NET으로 책 페이지 학습 후 예측
# - pages_data: train-5개, test-1개 => 데이터가 많이 부족함
# - 한계점 => 경계를 정확하게 판단 하기위해 많은 학습 데이터가 필요함
# - 이미지 데이터 증강으로 데이터 수를 늘려야 한다.
# - 새로운 객체 탐지 및 세그먼테이션 모델이 있는지 찾아 볼 것

# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd
import glob

import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Nadam
import tensorflow as tf
import tensorflow.python.keras.backend as k

from skimage.transform import resize

# %%
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 1


#데이터 경로 지정  
TRAIN_PATH = './page_data/train/'
TEST_PATH = './page_data/test/'

# UserWarning을 무시하는 설정(없음 OK)
warnings.filterwarnings('ignore', category=UserWarning, module='skimage')

#이미지 파일명을 리스트 형식으로 리턴  
train_imgs = glob.glob(TRAIN_PATH+'org/*.jpg')
train_masks = glob.glob(TRAIN_PATH+'seg/*.jpg')
test_imgs = glob.glob(TEST_PATH+'org/*.jpg')
test_masks = glob.glob(TEST_PATH+'seg/*.jpg')


#리스트 길이 리턴  
num_of_train_imgs = len(train_imgs)
num_of_train_masks = len(train_masks)
if num_of_train_imgs != num_of_train_masks:
    print('invalid datasets, please check train data')
    
#각이미지를 배열로 리턴
#image 
X_train = np.zeros((num_of_train_imgs, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
# mask
Y_train = np.zeros((num_of_train_masks, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
# Out:
# Getting and resizing train images and masks ...

# %%
for n in range(num_of_train_imgs):
    img = imread(train_imgs[n],as_gray=True)
    img = (img * 255).astype(np.uint8)
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img.reshape(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
    
    mask = imread(train_masks[n],as_gray=True)
    mask_resized = resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    Y_train[n] = mask_resized.reshape(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
    
# 테스트 이미지를 배열로 리턴
X_test = np.zeros((len(test_imgs), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_test = np.zeros((len(test_masks), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
print('Getting test images ... ')
sys.stdout.flush()

for n in range(len(test_imgs)):
    img = imread(test_imgs[n],as_gray=True)
    img = (img * 255).astype(np.uint8)
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img.reshape(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
    
    mask = imread(test_masks[n],as_gray=True)
    mask_resized = resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    Y_test[n] = mask_resized.reshape(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

print('Preparing is Done!')
# Out:
# Getting test images ...
# Preparing is Done!

# %%
###이미지 확인 #####
ix = random.randint(0, len(train_imgs))
# print(ix)
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title('org')
plt.imshow(X_train[ix] , cmap='gray')

plt.subplot(1,2,2)
plt.title('seg')
plt.imshow(Y_train[ix], cmap='gray')

# %%
# U-Net model 
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255.) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = BatchNormalization() (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same') (p1)
c2 = LeakyReLU()(c2)
c2 = BatchNormalization() (c2)
c2 = Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same') (c2)
c2 = LeakyReLU()(c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same') (p2)
c3 = LeakyReLU()(c3)
c3 = BatchNormalization() (c3)
c3 = Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same') (c3)
c3 = LeakyReLU()(c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), kernel_initializer='he_normal', padding='same') (p3)
c4 = LeakyReLU()(c4)
c4 = BatchNormalization() (c4)
c4 = Conv2D(128, (3, 3), kernel_initializer='he_normal', padding='same') (c4)
c4 = LeakyReLU()(c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = BatchNormalization() (c5)
c5 = Conv2D(256, (3, 3), activation='elu',kernel_initializer='he_normal', padding='same') (c5)

#===========================================

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), kernel_initializer='he_normal', padding='same') (u6)
c6 = LeakyReLU()(c6)
c6 = BatchNormalization() (c6)
c6 = Conv2D(128, (3, 3), kernel_initializer='he_normal', padding='same') (c6)
c6 = LeakyReLU()(c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same') (u7)
c7 = LeakyReLU()(c7)
c7 = BatchNormalization() (c7)
c7 = Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same') (c7)
c7 = LeakyReLU()(c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same') (u8)
c8 = LeakyReLU()(c8)
c8 = BatchNormalization() (c8)
c8 = Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same') (c8)
c8 = LeakyReLU()(c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = BatchNormalization(momentum=0.9) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])

# %%
model.compile(optimizer=Nadam(learning_rate=2e-5), loss='binary_crossentropy', metrics=['binary_accuracy','acc'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  lambda (Lambda)                (None, 256, 256, 1)  0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 256, 256, 16  160         ['lambda[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 16  2320        ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 16  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 32  4640        ['max_pooling2d[0][0]']
#                                 )
#
#  leaky_re_lu (LeakyReLU)        (None, 128, 128, 32  0           ['conv2d_2[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 32  128        ['leaky_re_lu[0][0]']
#  rmalization)                   )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 32  9248        ['batch_normalization_1[0][0]']
#                                 )
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 128, 128, 32  0           ['conv2d_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)  0           ['leaky_re_lu_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d_1[0][0]']
#  leaky_re_lu_2 (LeakyReLU)      (None, 64, 64, 64)   0           ['conv2d_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 64)  256         ['leaky_re_lu_2[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 64)   36928       ['batch_normalization_2[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 64, 64, 64)   0           ['conv2d_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)  0           ['leaky_re_lu_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 32, 32, 128)  0           ['conv2d_6[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 128)  512        ['leaky_re_lu_4[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 128)  147584      ['batch_normalization_3[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 32, 32, 128)  0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0          ['leaky_re_lu_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 256)  590080      ['batch_normalization_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 128)  131200     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'leaky_re_lu_5[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 32, 32, 128)  0           ['conv2d_10[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 128)  512        ['leaky_re_lu_6[0][0]']
#  rmalization)
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 128)  147584      ['batch_normalization_5[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 32, 32, 128)  0           ['conv2d_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 64)  32832       ['leaky_re_lu_7[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'leaky_re_lu_3[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_1[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 64, 64, 64)   0           ['conv2d_12[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 64)  256         ['leaky_re_lu_8[0][0]']
#  rmalization)
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_6[0][0]']
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 64, 64, 64)   0           ['conv2d_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 32  8224       ['leaky_re_lu_9[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'leaky_re_lu_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_2[0][0]']
#                                 )
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 128, 128, 32  0           ['conv2d_14[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 32  128        ['leaky_re_lu_10[0][0]']
#  rmalization)                   )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 32  9248        ['batch_normalization_7[0][0]']
#                                 )
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 128, 128, 32  0           ['conv2d_15[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 16  2064       ['leaky_re_lu_11[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 256, 256, 16  64         ['conv2d_16[0][0]']
#  rmalization)                   )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 16  2320        ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  17          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 1,943,761
# Trainable params: 1,942,289
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
checkpointer = ModelCheckpoint('model-page-003book.h5', verbose=1, save_best_only=True)
reduceLr = ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=7)

results = model.fit(X_train, 
                    Y_train, 
                    validation_split=0.1, 
                    batch_size=3, 
                    epochs=50,
                    callbacks=[reduceLr, checkpointer])
# Out:
# Epoch 1/50
# 6/6 [==============================] - ETA: 0s - loss: -17.0029 - binary_accuracy: 0.4684 - acc: 0.4684
# Epoch 1: val_loss improved from inf to -47.40559, saving model to model-page-003book.h5
# 6/6 [==============================] - 33s 2s/step - loss: -17.0029 - binary_accuracy: 0.4684 - acc: 0.4684 - val_loss: -47.4056 - val_binary_accuracy: 0.1074 - val_acc: 0.1074 - lr: 2.0000e-05
# Epoch 2/50
# 6/6 [==============================] - ETA: 0s - loss: -33.6059 - binary_accuracy: 0.4814 - acc: 0.4814
# Epoch 2: val_loss improved from -47.40559 to -47.65302, saving model to model-page-003book.h5
# 6/6 [==============================] - 12s 2s/step - loss: -33.6059 - binary_accuracy: 0.4814 - acc: 0.4814 - val_loss: -47.6530 - val_binary_accuracy: 0.1352 - val_acc: 0.1352 - lr: 2.0000e-05
# Epoch 3/50
# 6/6 [==============================] - ETA: 0s - loss: -53.8021 - binary_accuracy: 0.4923 - acc: 0.4923
# Epoch 3: val_loss improved from -47.65302 to -52.82896, saving model to model-page-003book.h5
# 6/6 [==============================] - 12s 2s/step - loss: -53.8021 - binary_accuracy: 0.4923 - acc: 0.4923 - val_loss: -52.8290 - val_binary_accuracy: 0.1498 - val_acc: 0.1498 - lr: 2.0000e-05
# Epoch 4/50
# 6/6 [==============================] - ETA: 0s - loss: -74.9179 - binary_accuracy: 0.4983 - acc: 0.4983
# Epoch 4: val_loss improved from -52.82896 to -62.19455, saving model to model-page-003book.h5
# 6/6 [==============================] - 12s 2s/step - loss: -74.9179 - binary_accuracy: 0.4983 - acc: 0.4983 - val_loss: -62.1945 - val_binary_accuracy: 0.1574 - val_acc: 0.1574 - lr: 2.0000e-05
# Epoch 5/50
# 6/6 [==============================] - ETA: 0s - loss: -96.4015 - binary_accuracy: 0.5013 - acc: 0.5013
# Epoch 5: val_loss improved from -62.19455 to -75.33867, saving model to model-page-003book.h5
# 6/6 [==============================] - 14s 2s/step - loss: -96.4015 - binary_accuracy: 0.5013 - acc: 0.5013 - val_loss: -75.3387 - val_binary_accuracy: 0.1568 - val_acc: 0.1568 - lr: 2.0000e-05
# Epoch 6/50
# 6/6 [==============================] - ETA: 0s - loss: -117.3545 - binary_accuracy: 0.5024 - acc: 0.5024
# Epoch 6: val_loss improved from -75.33867 to -91.48347, saving model to model-page-003book.h5
# 6/6 [==============================] - 13s 2s/step - loss: -117.3545 - binary_accuracy: 0.5024 - acc: 0.5024 - val_loss: -91.4835 - val_binary_accuracy: 0.1503 - val_acc: 0.1503 - lr: 2.0000e-05
# Epoch 7/50
# 6/6 [==============================] - ETA: 0s - loss: -138.0522 - binary_accuracy: 0.5013 - acc: 0.5013
# Epoch 7: val_loss improved from -91.48347 to -109.49461, saving model to model-page-003book.h5
# 6/6 [==============================] - 11s 2s/step - loss: -138.0522 - binary_accuracy: 0.5013 - acc: 0.5013 - val_loss: -109.4946 - val_binary_accuracy: 0.1434 - val_acc: 0.1434 - lr: 2.0000e-05
# Epoch 8/50
# 6/6 [==============================] - ETA: 0s - loss: -158.2495 - binary_accuracy: 0.5018 - acc: 0.5018
# Epoch 8: val_loss improved from -109.49461 to -130.49887, saving model to model-page-003book.h5
# 6/6 [==============================] - 10s 2s/step - loss: -158.2495 - binary_accuracy: 0.5018 - acc: 0.5018 - val_loss: -130.4989 - val_binary_accuracy: 0.1355 - val_acc: 0.1355 - lr: 2.0000e-05
# Epoch 9/50
# 6/6 [==============================] - ETA: 0s - loss: -177.6801 - binary_accuracy: 0.5002 - acc: 0.5002
# Epoch 9: val_loss improved from -130.49887 to -152.40996, saving model to model-page-003book.h5
# 6/6 [==============================] - 11s 2s/step - loss: -177.6801 - binary_accuracy: 0.5002 - acc: 0.5002 - val_loss: -152.4100 - val_binary_accuracy: 0.1331 - val_acc: 0.1331 - lr: 2.0000e-05
# Epoch 10/50
# 6/6 [==============================] - ETA: 0s - loss: -198.3176 - binary_accuracy: 0.5033 - acc: 0.5033
# Epoch 10: val_loss improved from -152.40996 to -174.22832, saving model to model-page-003book.h5
# 6/6 [==============================] - 10s 2s/step - loss: -198.3176 - binary_accuracy: 0.5033 - acc: 0.5033 - val_loss: -174.2283 - val_binary_accuracy: 0.1353 - val_acc: 0.1353 - lr: 2.0000e-05
# Epoch 11/50
# 6/6 [==============================] - ETA: 0s - loss: -219.0956 - binary_accuracy: 0.5042 - acc: 0.5042
# Epoch 11: val_loss improved from -174.22832 to -196.08351, saving model to model-page-003book.h5
# 6/6 [==============================] - 10s 2s/step - loss: -219.0956 - binary_accuracy: 0.5042 - acc: 0.5042 - val_loss: -196.0835 - val_binary_accuracy: 0.1393 - val_acc: 0.1393 - lr: 2.0000e-05
# Epoch 12/50
# 6/6 [==============================] - ETA: 0s - loss: -237.6825 - binary_accuracy: 0.5066 - acc: 0.5066
# Epoch 12: val_loss improved from -196.08351 to -217.27368, saving model to model-page-003book.h5
# 6/6 [==============================] - 12s 2s/step - loss: -237.6825 - binary_accuracy: 0.5066 - acc: 0.5066 - val_loss: -217.2737 - val_binary_accuracy: 0.1463 - val_acc: 0.1463 - lr: 2.0000e-05
# Epoch 13/50
# 6/6 [==============================] - ETA: 0s - loss: -256.8226 - binary_accuracy: 0.5059 - acc: 0.5059
# Epoch 13: val_loss improved from -217.27368 to -235.88698, saving model to model-page-003book.h5
# 6/6 [==============================] - 10s 2s/step - loss: -256.8226 - binary_accuracy: 0.5059 - acc: 0.5059 - val_loss: -235.8870 - val_binary_accuracy: 0.1583 - val_acc: 0.1583 - lr: 2.0000e-05
# Epoch 14/50
# 6/6 [==============================] - ETA: 0s - loss: -276.6871 - binary_accuracy: 0.5085 - acc: 0.5085
# Epoch 14: val_loss improved from -235.88698 to -254.09866, saving model to model-page-003book.h5
# 6/6 [==============================] - 9s 2s/step - loss: -276.6871 - binary_accuracy: 0.5085 - acc: 0.5085 - val_loss: -254.0987 - val_binary_accuracy: 0.1690 - val_acc: 0.1690 - lr: 2.0000e-05
# Epoch 15/50
# 6/6 [==============================] - ETA: 0s - loss: -297.0103 - binary_accuracy: 0.5105 - acc: 0.5105
# Epoch 15: val_loss improved from -254.09866 to -269.07208, saving model to model-page-003book.h5
# 6/6 [==============================] - 10s 2s/step - loss: -297.0103 - binary_accuracy: 0.5105 - acc: 0.5105 - val_loss: -269.0721 - val_binary_accuracy: 0.1838 - val_acc: 0.1838 - lr: 2.0000e-05
# Epoch 16/50
# 6/6 [==============================] - ETA: 0s - loss: -317.7442 - binary_accuracy: 0.5160 - acc: 0.5160
# Epoch 16: val_loss improved from -269.07208 to -284.11935, saving model to model-page-003book.h5
# 6/6 [==============================] - 12s 2s/step - loss: -317.7442 - binary_accuracy: 0.5160 - acc: 0.5160 - val_loss: -284.1194 - val_binary_accuracy: 0.1984 - val_acc: 0.1984 - lr: 2.0000e-05
# Epoch 17/50
# 6/6 [==============================] - ETA: 0s - loss: -339.4096 - binary_accuracy: 0.5215 - acc: 0.5215
# Epoch 17: val_loss improved from -284.11935 to -301.59283, saving model to model-page-003book.h5
# 6/6 [==============================] - 11s 2s/step - loss: -339.4096 - binary_accuracy: 0.5215 - acc: 0.5215 - val_loss: -301.5928 - val_binary_accuracy: 0.2124 - val_acc: 0.2124 - lr: 2.0000e-05
# Epoch 18/50
# 6/6 [==============================] - ETA: 0s - loss: -359.7455 - binary_accuracy: 0.5258 - acc: 0.5258
# Epoch 18: val_loss improved from -301.59283 to -329.19479, saving model to model-page-003book.h5
# 6/6 [==============================] - 10s 2s/step - loss: -359.7455 - binary_accuracy: 0.5258 - acc: 0.5258 - val_loss: -329.1948 - val_binary_accuracy: 0.2186 - val_acc: 0.2186 - lr: 2.0000e-05
# Epoch 19/50
# 6/6 [==============================] - ETA: 0s - loss: -380.1390 - binary_accuracy: 0.5301 - acc: 0.5301
# Epoch 19: val_loss improved from -329.19479 to -349.45288, saving model to model-page-003book.h5
# 6/6 [==============================] - 10s 2s/step - loss: -380.1390 - binary_accuracy: 0.5301 - acc: 0.5301 - val_loss: -349.4529 - val_binary_accuracy: 0.2367 - val_acc: 0.2367 - lr: 2.0000e-05
# Epoch 20/50
# 6/6 [==============================] - ETA: 0s - loss: -400.4602 - binary_accuracy: 0.5318 - acc: 0.5318
# Epoch 20: val_loss improved from -349.45288 to -383.31940, saving model to model-page-003book.h5
# 6/6 [==============================] - 9s 2s/step - loss: -400.4602 - binary_accuracy: 0.5318 - acc: 0.5318 - val_loss: -383.3194 - val_binary_accuracy: 0.2369 - val_acc: 0.2369 - lr: 2.0000e-05
# Epoch 21/50
# 6/6 [==============================] - ETA: 0s - loss: -422.7393 - binary_accuracy: 0.5400 - acc: 0.5400
# Epoch 21: val_loss improved from -383.31940 to -386.69000, saving model to model-page-003book.h5
# 6/6 [==============================] - 10s 2s/step - loss: -422.7393 - binary_accuracy: 0.5400 - acc: 0.5400 - val_loss: -386.6900 - val_binary_accuracy: 0.2874 - val_acc: 0.2874 - lr: 2.0000e-05
# Epoch 22/50
# 6/6 [==============================] - ETA: 0s - loss: -441.8231 - binary_accuracy: 0.5452 - acc: 0.5452
# Epoch 22: val_loss improved from -386.69000 to -414.87094, saving model to model-page-003book.h5
# 6/6 [==============================] - 11s 2s/step - loss: -441.8231 - binary_accuracy: 0.5452 - acc: 0.5452 - val_loss: -414.8709 - val_binary_accuracy: 0.3231 - val_acc: 0.3231 - lr: 2.0000e-05
# Epoch 23/50
# 6/6 [==============================] - ETA: 0s - loss: -459.1967 - binary_accuracy: 0.5466 - acc: 0.5466
# Epoch 23: val_loss improved from -414.87094 to -480.14362, saving model to model-page-003book.h5
# 6/6 [==============================] - 11s 2s/step - loss: -459.1967 - binary_accuracy: 0.5466 - acc: 0.5466 - val_loss: -480.1436 - val_binary_accuracy: 0.2891 - val_acc: 0.2891 - lr: 2.0000e-05
# Epoch 24/50
# 6/6 [==============================] - ETA: 0s - loss: -479.8409 - binary_accuracy: 0.5549 - acc: 0.5549
# Epoch 24: val_loss did not improve from -480.14362
# 6/6 [==============================] - 9s 1s/step - loss: -479.8409 - binary_accuracy: 0.5549 - acc: 0.5549 - val_loss: -464.9223 - val_binary_accuracy: 0.3706 - val_acc: 0.3706 - lr: 2.0000e-05
# Epoch 25/50
# 6/6 [==============================] - ETA: 0s - loss: -498.9773 - binary_accuracy: 0.5557 - acc: 0.5557
# Epoch 25: val_loss did not improve from -480.14362
# 6/6 [==============================] - 8s 1s/step - loss: -498.9773 - binary_accuracy: 0.5557 - acc: 0.5557 - val_loss: -457.2070 - val_binary_accuracy: 0.4026 - val_acc: 0.4026 - lr: 2.0000e-05
# Epoch 26/50
# 6/6 [==============================] - ETA: 0s - loss: -510.5994 - binary_accuracy: 0.5607 - acc: 0.5607
# Epoch 26: val_loss improved from -480.14362 to -507.15381, saving model to model-page-003book.h5
# 6/6 [==============================] - 9s 2s/step - loss: -510.5994 - binary_accuracy: 0.5607 - acc: 0.5607 - val_loss: -507.1538 - val_binary_accuracy: 0.4018 - val_acc: 0.4018 - lr: 2.0000e-05
# Epoch 27/50
# 6/6 [==============================] - ETA: 0s - loss: -531.6864 - binary_accuracy: 0.5671 - acc: 0.5671
# Epoch 27: val_loss did not improve from -507.15381
# 6/6 [==============================] - 7s 1s/step - loss: -531.6864 - binary_accuracy: 0.5671 - acc: 0.5671 - val_loss: -490.5086 - val_binary_accuracy: 0.4415 - val_acc: 0.4415 - lr: 2.0000e-05
# Epoch 28/50
# 6/6 [==============================] - ETA: 0s - loss: -550.4477 - binary_accuracy: 0.5689 - acc: 0.5689
# Epoch 28: val_loss did not improve from -507.15381
# 6/6 [==============================] - 7s 1s/step - loss: -550.4477 - binary_accuracy: 0.5689 - acc: 0.5689 - val_loss: -487.6210 - val_binary_accuracy: 0.4586 - val_acc: 0.4586 - lr: 2.0000e-05
# Epoch 29/50
# 6/6 [==============================] - ETA: 0s - loss: -566.8333 - binary_accuracy: 0.5770 - acc: 0.5770
# Epoch 29: val_loss did not improve from -507.15381
# 6/6 [==============================] - 8s 1s/step - loss: -566.8333 - binary_accuracy: 0.5770 - acc: 0.5770 - val_loss: -506.8743 - val_binary_accuracy: 0.4723 - val_acc: 0.4723 - lr: 2.0000e-05
# Epoch 30/50
# 6/6 [==============================] - ETA: 0s - loss: -585.3345 - binary_accuracy: 0.5760 - acc: 0.5760
# Epoch 30: val_loss improved from -507.15381 to -532.09424, saving model to model-page-003book.h5
# 6/6 [==============================] - 9s 2s/step - loss: -585.3345 - binary_accuracy: 0.5760 - acc: 0.5760 - val_loss: -532.0942 - val_binary_accuracy: 0.4674 - val_acc: 0.4674 - lr: 2.0000e-05
# Epoch 31/50
# 6/6 [==============================] - ETA: 0s - loss: -601.5706 - binary_accuracy: 0.5821 - acc: 0.5821
# Epoch 31: val_loss did not improve from -532.09424
# 6/6 [==============================] - 7s 1s/step - loss: -601.5706 - binary_accuracy: 0.5821 - acc: 0.5821 - val_loss: -466.1322 - val_binary_accuracy: 0.5142 - val_acc: 0.5142 - lr: 2.0000e-05
# Epoch 32/50
# 6/6 [==============================] - ETA: 0s - loss: -617.9093 - binary_accuracy: 0.5873 - acc: 0.5873
# Epoch 32: val_loss did not improve from -532.09424
# 6/6 [==============================] - 7s 1s/step - loss: -617.9093 - binary_accuracy: 0.5873 - acc: 0.5873 - val_loss: -521.0238 - val_binary_accuracy: 0.5063 - val_acc: 0.5063 - lr: 2.0000e-05
# Epoch 33/50
# 6/6 [==============================] - ETA: 0s - loss: -634.9660 - binary_accuracy: 0.5917 - acc: 0.5917
# Epoch 33: val_loss did not improve from -532.09424
# 6/6 [==============================] - 7s 1s/step - loss: -634.9660 - binary_accuracy: 0.5917 - acc: 0.5917 - val_loss: -519.3342 - val_binary_accuracy: 0.5144 - val_acc: 0.5144 - lr: 2.0000e-05
# Epoch 34/50
# 6/6 [==============================] - ETA: 0s - loss: -650.1974 - binary_accuracy: 0.5948 - acc: 0.5948
# Epoch 34: val_loss did not improve from -532.09424
# 6/6 [==============================] - 7s 1s/step - loss: -650.1974 - binary_accuracy: 0.5948 - acc: 0.5948 - val_loss: -510.3433 - val_binary_accuracy: 0.5267 - val_acc: 0.5267 - lr: 2.0000e-05
# Epoch 35/50
# 6/6 [==============================] - ETA: 0s - loss: -669.3494 - binary_accuracy: 0.5988 - acc: 0.5988
# Epoch 35: val_loss did not improve from -532.09424
# 6/6 [==============================] - 8s 1s/step - loss: -669.3494 - binary_accuracy: 0.5988 - acc: 0.5988 - val_loss: -515.5115 - val_binary_accuracy: 0.5278 - val_acc: 0.5278 - lr: 2.0000e-05
# Epoch 36/50
# 6/6 [==============================] - ETA: 0s - loss: -684.7628 - binary_accuracy: 0.5997 - acc: 0.5997
# Epoch 36: val_loss did not improve from -532.09424
# 6/6 [==============================] - 8s 1s/step - loss: -684.7628 - binary_accuracy: 0.5997 - acc: 0.5997 - val_loss: -525.3121 - val_binary_accuracy: 0.5286 - val_acc: 0.5286 - lr: 2.0000e-05
# Epoch 37/50
# 6/6 [==============================] - ETA: 0s - loss: -700.5561 - binary_accuracy: 0.6048 - acc: 0.6048
# Epoch 37: val_loss improved from -532.09424 to -615.96552, saving model to model-page-003book.h5
# 6/6 [==============================] - 9s 2s/step - loss: -700.5561 - binary_accuracy: 0.6048 - acc: 0.6048 - val_loss: -615.9655 - val_binary_accuracy: 0.5080 - val_acc: 0.5080 - lr: 2.0000e-05
# Epoch 38/50
# 6/6 [==============================] - ETA: 0s - loss: -714.6173 - binary_accuracy: 0.6094 - acc: 0.6094
# Epoch 38: val_loss did not improve from -615.96552
# 6/6 [==============================] - 7s 1s/step - loss: -714.6173 - binary_accuracy: 0.6094 - acc: 0.6094 - val_loss: -576.8798 - val_binary_accuracy: 0.5261 - val_acc: 0.5261 - lr: 2.0000e-05
# Epoch 39/50
# 6/6 [==============================] - ETA: 0s - loss: -727.7667 - binary_accuracy: 0.6088 - acc: 0.6088
# Epoch 39: val_loss improved from -615.96552 to -679.97998, saving model to model-page-003book.h5
# 6/6 [==============================] - 9s 2s/step - loss: -727.7667 - binary_accuracy: 0.6088 - acc: 0.6088 - val_loss: -679.9800 - val_binary_accuracy: 0.5050 - val_acc: 0.5050 - lr: 2.0000e-05
# Epoch 40/50
# 6/6 [==============================] - ETA: 0s - loss: -746.1313 - binary_accuracy: 0.6153 - acc: 0.6153
# Epoch 40: val_loss did not improve from -679.97998
# 6/6 [==============================] - 10s 2s/step - loss: -746.1313 - binary_accuracy: 0.6153 - acc: 0.6153 - val_loss: -645.3909 - val_binary_accuracy: 0.5142 - val_acc: 0.5142 - lr: 2.0000e-05
# Epoch 41/50
# 6/6 [==============================] - ETA: 0s - loss: -759.9573 - binary_accuracy: 0.6200 - acc: 0.6200
# Epoch 41: val_loss did not improve from -679.97998
# 6/6 [==============================] - 10s 2s/step - loss: -759.9573 - binary_accuracy: 0.6200 - acc: 0.6200 - val_loss: -650.2352 - val_binary_accuracy: 0.5251 - val_acc: 0.5251 - lr: 2.0000e-05
# Epoch 42/50
# 6/6 [==============================] - ETA: 0s - loss: -774.4826 - binary_accuracy: 0.6211 - acc: 0.6211
# Epoch 42: val_loss did not improve from -679.97998
# 6/6 [==============================] - 10s 2s/step - loss: -774.4826 - binary_accuracy: 0.6211 - acc: 0.6211 - val_loss: -623.5262 - val_binary_accuracy: 0.5348 - val_acc: 0.5348 - lr: 2.0000e-05
# Epoch 43/50
# 6/6 [==============================] - ETA: 0s - loss: -784.9930 - binary_accuracy: 0.6234 - acc: 0.6234
# Epoch 43: val_loss improved from -679.97998 to -693.67682, saving model to model-page-003book.h5
# 6/6 [==============================] - 11s 2s/step - loss: -784.9930 - binary_accuracy: 0.6234 - acc: 0.6234 - val_loss: -693.6768 - val_binary_accuracy: 0.5191 - val_acc: 0.5191 - lr: 2.0000e-05
# Epoch 44/50
# 6/6 [==============================] - ETA: 0s - loss: -799.5588 - binary_accuracy: 0.6247 - acc: 0.6247
# Epoch 44: val_loss improved from -693.67682 to -715.09869, saving model to model-page-003book.h5
# 6/6 [==============================] - 10s 2s/step - loss: -799.5588 - binary_accuracy: 0.6247 - acc: 0.6247 - val_loss: -715.0987 - val_binary_accuracy: 0.5152 - val_acc: 0.5152 - lr: 2.0000e-05
# Epoch 45/50
# 6/6 [==============================] - ETA: 0s - loss: -814.6106 - binary_accuracy: 0.6250 - acc: 0.6250
# Epoch 45: val_loss improved from -715.09869 to -745.12573, saving model to model-page-003book.h5
# 6/6 [==============================] - 10s 2s/step - loss: -814.6106 - binary_accuracy: 0.6250 - acc: 0.6250 - val_loss: -745.1257 - val_binary_accuracy: 0.5113 - val_acc: 0.5113 - lr: 2.0000e-05
# Epoch 46/50
# 6/6 [==============================] - ETA: 0s - loss: -832.2170 - binary_accuracy: 0.6293 - acc: 0.6293
# Epoch 46: val_loss did not improve from -745.12573
# 6/6 [==============================] - 8s 1s/step - loss: -832.2170 - binary_accuracy: 0.6293 - acc: 0.6293 - val_loss: -709.9126 - val_binary_accuracy: 0.5263 - val_acc: 0.5263 - lr: 2.0000e-05
# Epoch 47/50
# 6/6 [==============================] - ETA: 0s - loss: -842.3817 - binary_accuracy: 0.6315 - acc: 0.6315
# Epoch 47: val_loss did not improve from -745.12573
# 6/6 [==============================] - 8s 1s/step - loss: -842.3817 - binary_accuracy: 0.6315 - acc: 0.6315 - val_loss: -718.0030 - val_binary_accuracy: 0.5243 - val_acc: 0.5243 - lr: 2.0000e-05
# Epoch 48/50
# 6/6 [==============================] - ETA: 0s - loss: -855.4003 - binary_accuracy: 0.6315 - acc: 0.6315
# Epoch 48: val_loss improved from -745.12573 to -770.57971, saving model to model-page-003book.h5
# 6/6 [==============================] - 9s 2s/step - loss: -855.4003 - binary_accuracy: 0.6315 - acc: 0.6315 - val_loss: -770.5797 - val_binary_accuracy: 0.5177 - val_acc: 0.5177 - lr: 2.0000e-05
# Epoch 49/50
# 6/6 [==============================] - ETA: 0s - loss: -872.6883 - binary_accuracy: 0.6342 - acc: 0.6342
# Epoch 49: val_loss did not improve from -770.57971
# 6/6 [==============================] - 7s 1s/step - loss: -872.6883 - binary_accuracy: 0.6342 - acc: 0.6342 - val_loss: -769.6341 - val_binary_accuracy: 0.5142 - val_acc: 0.5142 - lr: 2.0000e-05
# Epoch 50/50
# 6/6 [==============================] - ETA: 0s - loss: -882.5789 - binary_accuracy: 0.6350 - acc: 0.6350
# Epoch 50: val_loss did not improve from -770.57971
# 6/6 [==============================] - 7s 1s/step - loss: -882.5789 - binary_accuracy: 0.6350 - acc: 0.6350 - val_loss: -767.7657 - val_binary_accuracy: 0.5159 - val_acc: 0.5159 - lr: 2.0000e-05

# %%
model = load_model('model-page-003book.h5')

# %%
preds_test = model.predict(X_test, verbose=1)

#픽셀  평가 결과를 0.5의 임계치로 0 or 255로 변환(평가 결과를 바이너리 이미지로 변환).
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# # 임의 결과로 하나를 리턴 받아 표시 
ix = random.randint(0, len(preds_test_t))
ix = 0
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.title('org')
plt.imshow(X_test[ix].reshape(IMG_HEIGHT, IMG_WIDTH), cmap='gray')

plt.subplot(1,3,2)
plt.title('seg')
plt.imshow(Y_test[ix].reshape(IMG_HEIGHT, IMG_WIDTH), cmap='gray')

plt.subplot(1,3,3)
plt.title('pred_seg')
plt.imshow(np.squeeze(preds_test_t[ix].reshape(IMG_HEIGHT, IMG_WIDTH)), cmap='gray')
# Out:
# 1/1 [==============================] - 1s 941ms/step

# %%
preds_test = model.predict(X_train, verbose=1)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

ix = 11
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.title('org')
plt.imshow(X_train[ix].reshape(IMG_HEIGHT, IMG_WIDTH), cmap='gray')

plt.subplot(1, 3, 2)
plt.title('seg')
plt.imshow(Y_train[ix].reshape(IMG_HEIGHT, IMG_WIDTH), cmap='gray')

plt.subplot(1, 3, 3)
plt.title('predicted_seg')
plt.imshow(np.squeeze(preds_test_t[ix].reshape(IMG_HEIGHT, IMG_WIDTH)), cmap='gray')
# Out:
# 1/1 [==============================] - 2s 2s/step
